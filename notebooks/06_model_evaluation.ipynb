# %% [markdown]
# # Step 06: Model Evaluation & Prediction Pipeline Test
#
# Loading saved `.pkl` model artifacts, inspecting feature importances, and evaluating single-student inference.

# %%
import sys, os
sys.path.append("..")
import pandas as pd
from src.predict import StudentPlacementPredictor

# %%
predictor = StudentPlacementPredictor(model_path="../models/final_model.pkl", feature_info_path="../models/feature_info.pkl")

# %%
# Display comparison table
results_df = pd.read_csv("../reports/model_results.csv")
results_df
