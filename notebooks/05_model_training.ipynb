# %% [markdown]
# # Step 05: Model Training, Cross-Validation & Hyperparameter Tuning
#
# Evaluating baseline and multiple machine learning models using 5-Fold Stratified Cross-Validation and GridSearchCV hyperparameter optimization.

# %%
import sys, os
sys.path.append("..")
from src.train import train_and_evaluate_all_models

# %%
best_name, best_metrics, model_path = train_and_evaluate_all_models(
    raw_data_path="../data/raw/placement_data_raw.csv",
    output_dir="../models",
    reports_dir="../reports"
)
print(f"Best Model: {best_name}, F1: {best_metrics['F1 Score']}")
