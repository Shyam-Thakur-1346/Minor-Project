# %% [markdown]
# # Step 03: Exploratory Data Analysis (EDA)
#
# Visualizing target distributions, feature correlations, CGPA vs placement status, and core skill distributions.

# %%
import sys, os
sys.path.append("..")
import pandas as pd
from src.feature_engineering import create_engineered_features
from src.evaluate import generate_eda_figures

# %%
df_proc = pd.read_csv("../data/processed/student_placement_processed.csv")
df_feat = create_engineered_features(df_proc)
generate_eda_figures(df_feat, "../reports/figures")
print("EDA figures generated successfully.")
