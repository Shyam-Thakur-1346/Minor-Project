# %% [markdown]
# # Step 04: Feature Engineering
#
# Creating domain-specific composite indices (technical_skill_avg, soft_skill_avg, academic_score_index, experience_score, overall_readiness_index) and checking multicollinearity.

# %%
import sys, os
sys.path.append("..")
import pandas as pd
from src.feature_engineering import create_engineered_features, check_feature_correlations

# %%
df_proc = pd.read_csv("../data/processed/student_placement_processed.csv")
df_feat = create_engineered_features(df_proc)
check_feature_correlations(df_feat)
df_feat[["academic_score_index", "technical_skill_avg", "soft_skill_avg", "experience_score", "overall_readiness_index"]].head()
