# %% [markdown]
# # Step 02: Data Cleaning & Split
#
# This notebook cleans raw dataset records, handles duplicate rows, corrects out-of-range numerical metrics, and performs stratified train-test splitting.

# %%
import sys, os
sys.path.append("..")
import pandas as pd
from src.preprocessing import clean_raw_data, split_and_save_data

# %%
df_raw = pd.read_csv("../data/raw/placement_data_raw.csv")
df_clean = clean_raw_data(df_raw)
print("Cleaned shape:", df_clean.shape)

# %%
X_tr, X_te, y_tr, y_te = split_and_save_data(df_clean, output_dir="../data/processed")
